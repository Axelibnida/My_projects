# %% [markdown]
# # Project: Using data from a food products database
#
# ---
#
# In this notebook **Data_cleaning**, I am cleaning the data, since the database is relatively big *(320772, 162)* and the data quite dirty (missing data, non-relevant variables, outliers, unusable dtypes, etc.)
#
# I then export the data into a less heavy .csv file, and do the analysis in the notebook **Data_analysis**.
#
# ---
#
# ## Resources
#
# Database from this website:
# https://world.openfoodfacts.org/
#
# Variables describe: https://world.openfoodfacts.org/data/data-fields.txt
#
# ---
#
# # Table of contents
#
# [1. Data information](#1)
#
# [2. Cleaning: Quantitative features](#2)
#
# - [*_100g* data](#2.1)
#     - [*_100g* - Data information](#2.1.1)
#     - [*_100g* - Near-empty columns](#2.1.2)
#     - [*_100g* - Outliers (w/o `energy_100g`)](#2.1.3)
#     - [*_100g* - Outliers: `energy_100g`](#2.1.4)
#     - [*_100g* - Outliers 2](#2.1.5)
#     - [*_100g* - NaNs](#2.1.6)
#
# [3. Cleaning: Qualitative features](#3)
#
# - [1) Qualitative features - Data information](#3.1)
# - [2) Near-empty columns](#3.2)
# - [3) `code`](#3.3)
# - [4) NaNs](#3.4)
# - [5) Variables](#3.5)
#     - [`date_created`](#date_created)
#     - [`last_modified`](#last_modified)
#     - [`countries_tags`](#countries_tags)
#     - [`brands_tags`](#brands_tags)
#     - [`states`](#states)
#     - [`additives`](#additives)
#     - [`ingredients_text`](#ingredients_text)
#     - [`nutrition_grade_fr`](#nutrition_grade_fr)
#     - [`url`](#url)
#     - [`creator`](#creator)
#     - [`product_name`](#product_name)
#     - [`additives_n`](#additives_n)
#     - [`ingredients_from_palm_oil_n`](#ingredients_from_palm_oil_n)
#     - [`ingredients_that_may_be_from_palm_oil_n`](#ingredients_that_may_be_from_palm_oil_n)
#
# [4. Data export](#4)
#
# ---
#
# **Libraries import**

# %%
import numpy as np

import pandas as pd
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

import seaborn as sns
import matplotlib.pyplot as plt
#from datetime import datetime

# %% [markdown]
# **Functions**

# %%
def regularize(column):
    """
    Function to regularize a string dtype column.
    input: series
    output: series
    """
    print('Before regularization:', column.nunique())
    regularized_column = column.str.lower()
    #dtype, iso
    #remove les accents
    #strip, lstrip, rstrip
    #peutêtre couper/remove les longues chaînes
    #(((librairy ntlt (enelever les mots communs))))
    print('After regularization:', regularized_column.nunique())
    
    return regularized_column

# %% [markdown]
# **Data import**

# %%
data = pd.read_csv('fr.openfoodfacts.org.products.csv', sep='\t', low_memory=False)
data_origin = data.copy()

# %% [markdown]
# <a name='1'></a>
# # 1. Data information

# %%
print('Shape of data:', data.shape)
display(data.head(3))

#display(data.describe())
#print(data.nunique())
# Out:
# Shape of data: (320772, 162)
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# 1  0000000004530  http://world-fr.openfoodfacts.org/produit/0000...
# 2  0000000004559  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
#
#   generic_name quantity  ... ph_100g fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...     NaN                         NaN
# 1          NaN      NaN  ...     NaN                         NaN
# 2          NaN      NaN  ...     NaN                         NaN
#
#   collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 0                              NaN        NaN             NaN
# 1                              NaN        NaN             NaN
# 2                              NaN        NaN             NaN
#
#   carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 0                   NaN                     NaN                     NaN
# 1                   NaN                    14.0                    14.0
# 2                   NaN                     0.0                     0.0
#
#   glycemic-index_100g water-hardness_100g
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
#
# [3 rows x 162 columns]

# %%
#Removing empty lines (0)
data = data.dropna(how='all', axis=0)

#Removing empty columns
data = data.dropna(how='all', axis=1)

print(data.shape)
# Out:
# (320772, 146)

# %%
data_info = pd.DataFrame({'Column': data.columns,
                          'Non-Null Count': len(data)-data.isnull().sum(),
                          'n-unique': data.nunique(),
                          'Dtype': data.dtypes})

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_info)
# Out:
#                                                                                 Column  \
# code                                                                              code
# url                                                                                url
# creator                                                                        creator
# created_t                                                                    created_t
# created_datetime                                                      created_datetime
# last_modified_t                                                        last_modified_t
# last_modified_datetime                                          last_modified_datetime
# product_name                                                              product_name
# generic_name                                                              generic_name
# quantity                                                                      quantity
# packaging                                                                    packaging
# packaging_tags                                                          packaging_tags
# brands                                                                          brands
# brands_tags                                                                brands_tags
# categories                                                                  categories
# categories_tags                                                        categories_tags
# categories_fr                                                            categories_fr
# origins                                                                        origins
# origins_tags                                                              origins_tags
# manufacturing_places                                              manufacturing_places
# manufacturing_places_tags                                    manufacturing_places_tags
# labels                                                                          labels
# labels_tags                                                                labels_tags
# labels_fr                                                                    labels_fr
# emb_codes                                                                    emb_codes
# emb_codes_tags                                                          emb_codes_tags
# first_packaging_code_geo                                      first_packaging_code_geo
# cities                                                                          cities
# cities_tags                                                                cities_tags
# purchase_places                                                        purchase_places
# stores                                                                          stores
# countries                                                                    countries
# countries_tags                                                          countries_tags
# countries_fr                                                              countries_fr
# ingredients_text                                                      ingredients_text
# allergens                                                                    allergens
# allergens_fr                                                              allergens_fr
# traces                                                                          traces
# traces_tags                                                                traces_tags
# traces_fr                                                                    traces_fr
# serving_size                                                              serving_size
# additives_n                                                                additives_n
# additives                                                                    additives
# additives_tags                                                          additives_tags
# additives_fr                                                              additives_fr
# ingredients_from_palm_oil_n                                ingredients_from_palm_oil_n
# ingredients_from_palm_oil_tags                          ingredients_from_palm_oil_tags
# ingredients_that_may_be_from_palm_oil_n        ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil_tags  ingredients_that_may_be_from_palm_oil_tags
# nutrition_grade_fr                                                  nutrition_grade_fr
# pnns_groups_1                                                            pnns_groups_1
# pnns_groups_2                                                            pnns_groups_2
# states                                                                          states
# states_tags                                                                states_tags
# states_fr                                                                    states_fr
# main_category                                                            main_category
# main_category_fr                                                      main_category_fr
# image_url                                                                    image_url
# image_small_url                                                        image_small_url
# energy_100g                                                                energy_100g
# energy-from-fat_100g                                              energy-from-fat_100g
# fat_100g                                                                      fat_100g
# saturated-fat_100g                                                  saturated-fat_100g
# caprylic-acid_100g                                                  caprylic-acid_100g
# capric-acid_100g                                                      capric-acid_100g
# lauric-acid_100g                                                      lauric-acid_100g
# myristic-acid_100g                                                  myristic-acid_100g
# palmitic-acid_100g                                                  palmitic-acid_100g
# stearic-acid_100g                                                    stearic-acid_100g
# arachidic-acid_100g                                                arachidic-acid_100g
# behenic-acid_100g                                                    behenic-acid_100g
# montanic-acid_100g                                                  montanic-acid_100g
# monounsaturated-fat_100g                                      monounsaturated-fat_100g
# polyunsaturated-fat_100g                                      polyunsaturated-fat_100g
# omega-3-fat_100g                                                      omega-3-fat_100g
# alpha-linolenic-acid_100g                                    alpha-linolenic-acid_100g
# eicosapentaenoic-acid_100g                                  eicosapentaenoic-acid_100g
# docosahexaenoic-acid_100g                                    docosahexaenoic-acid_100g
# omega-6-fat_100g                                                      omega-6-fat_100g
# linoleic-acid_100g                                                  linoleic-acid_100g
# arachidonic-acid_100g                                            arachidonic-acid_100g
# gamma-linolenic-acid_100g                                    gamma-linolenic-acid_100g
# dihomo-gamma-linolenic-acid_100g                      dihomo-gamma-linolenic-acid_100g
# omega-9-fat_100g                                                      omega-9-fat_100g
# oleic-acid_100g                                                        oleic-acid_100g
# gondoic-acid_100g                                                    gondoic-acid_100g
# trans-fat_100g                                                          trans-fat_100g
# cholesterol_100g                                                      cholesterol_100g
# carbohydrates_100g                                                  carbohydrates_100g
# sugars_100g                                                                sugars_100g
# sucrose_100g                                                              sucrose_100g
# glucose_100g                                                              glucose_100g
# fructose_100g                                                            fructose_100g
# lactose_100g                                                              lactose_100g
# maltose_100g                                                              maltose_100g
# maltodextrins_100g                                                  maltodextrins_100g
# starch_100g                                                                starch_100g
# polyols_100g                                                              polyols_100g
# fiber_100g                                                                  fiber_100g
# proteins_100g                                                            proteins_100g
# casein_100g                                                                casein_100g
# serum-proteins_100g                                                serum-proteins_100g
# nucleotides_100g                                                      nucleotides_100g
# salt_100g                                                                    salt_100g
# sodium_100g                                                                sodium_100g
# alcohol_100g                                                              alcohol_100g
# vitamin-a_100g                                                          vitamin-a_100g
# beta-carotene_100g                                                  beta-carotene_100g
# vitamin-d_100g                                                          vitamin-d_100g
# vitamin-e_100g                                                          vitamin-e_100g
# vitamin-k_100g                                                          vitamin-k_100g
# vitamin-c_100g                                                          vitamin-c_100g
# vitamin-b1_100g                                                        vitamin-b1_100g
# vitamin-b2_100g                                                        vitamin-b2_100g
# vitamin-pp_100g                                                        vitamin-pp_100g
# vitamin-b6_100g                                                        vitamin-b6_100g
# vitamin-b9_100g                                                        vitamin-b9_100g
# folates_100g                                                              folates_100g
# vitamin-b12_100g                                                      vitamin-b12_100g
# biotin_100g                                                                biotin_100g
# pantothenic-acid_100g                                            pantothenic-acid_100g
# silica_100g                                                                silica_100g
# bicarbonate_100g                                                      bicarbonate_100g
# potassium_100g                                                          potassium_100g
# chloride_100g                                                            chloride_100g
# calcium_100g                                                              calcium_100g
# phosphorus_100g                                                        phosphorus_100g
# iron_100g                                                                    iron_100g
# magnesium_100g                                                          magnesium_100g
# zinc_100g                                                                    zinc_100g
# copper_100g                                                                copper_100g
# manganese_100g                                                          manganese_100g
# fluoride_100g                                                            fluoride_100g
# selenium_100g                                                            selenium_100g
# chromium_100g                                                            chromium_100g
# molybdenum_100g                                                        molybdenum_100g
# iodine_100g                                                                iodine_100g
# caffeine_100g                                                            caffeine_100g
# taurine_100g                                                              taurine_100g
# ph_100g                                                                        ph_100g
# fruits-vegetables-nuts_100g                                fruits-vegetables-nuts_100g
# collagen-meat-protein-ratio_100g                      collagen-meat-protein-ratio_100g
# cocoa_100g                                                                  cocoa_100g
# carbon-footprint_100g                                            carbon-footprint_100g
# nutrition-score-fr_100g                                        nutrition-score-fr_100g
# nutrition-score-uk_100g                                        nutrition-score-uk_100g
#
#                                             Non-Null Count  n-unique    Dtype
# code                                                320749    320749   object
# url                                                 320749    320749   object
# creator                                             320770      3535   object
# created_t                                           320769    189567   object
# created_datetime                                    320763    189568   object
# last_modified_t                                     320772    180495   object
# last_modified_datetime                              320772    180495   object
# product_name                                        303010    221347   object
# generic_name                                         52795     38584   object
# quantity                                            104819     13826   object
# packaging                                            78960     14547   object
# packaging_tags                                       78961     12064   object
# brands                                              292360     58784   object
# brands_tags                                         292352     50253   object
# categories                                           84410     36982   object
# categories_tags                                      84389     21142   object
# categories_fr                                        84411     21152   object
# origins                                              22190      4840   object
# origins_tags                                         22153      4372   object
# manufacturing_places                                 36501      7308   object
# manufacturing_places_tags                            36495      6736   object
# labels                                               46559     18114   object
# labels_tags                                          46644     13653   object
# labels_fr                                            46666     13655   object
# emb_codes                                            29306      8462   object
# emb_codes_tags                                       29303      8158   object
# first_packaging_code_geo                             18803      1602   object
# cities                                                  23         3   object
# cities_tags                                          20320      2572   object
# purchase_places                                      58193      5120   object
# stores                                               51722      3259   object
# countries                                           320492      1434   object
# countries_tags                                      320492       725   object
# countries_fr                                        320492       722   object
# ingredients_text                                    248962    205520   object
# allergens                                            28344     12939   object
# allergens_fr                                            19        19   object
# traces                                               24353      8378   object
# traces_tags                                          24329      3578   object
# traces_fr                                            24352      3584   object
# serving_size                                        211331     25423   object
# additives_n                                         248939        31  float64
# additives                                           248905    196069   object
# additives_tags                                      154680     41537   object
# additives_fr                                        154680     41537   object
# ingredients_from_palm_oil_n                         248939         3  float64
# ingredients_from_palm_oil_tags                        4835        14   object
# ingredients_that_may_be_from_palm_oil_n             248939         7  float64
# ingredients_that_may_be_from_palm_oil_tags           11696       160   object
# nutrition_grade_fr                                  221210         5   object
# pnns_groups_1                                        91513        14   object
# pnns_groups_2                                        94491        42   object
# states                                              320726      1021   object
# states_tags                                         320726      1021   object
# states_fr                                           320726      1021   object
# main_category                                        84366      3543   object
# main_category_fr                                     84366      3543   object
# image_url                                            75836     75836   object
# image_small_url                                      75836     75836   object
# energy_100g                                         261113      3997  float64
# energy-from-fat_100g                                   857       335  float64
# fat_100g                                            243891      3378  float64
# saturated-fat_100g                                  229554      2197  float64
# caprylic-acid_100g                                       1         1  float64
# capric-acid_100g                                         2         2  float64
# lauric-acid_100g                                         4         4  float64
# myristic-acid_100g                                       1         1  float64
# palmitic-acid_100g                                       1         1  float64
# stearic-acid_100g                                        1         1  float64
# arachidic-acid_100g                                     24        17  float64
# behenic-acid_100g                                       23        15  float64
# montanic-acid_100g                                       1         1  float64
# monounsaturated-fat_100g                             22823      1066  float64
# polyunsaturated-fat_100g                             22859       945  float64
# omega-3-fat_100g                                       841       225  float64
# alpha-linolenic-acid_100g                              186       112  float64
# eicosapentaenoic-acid_100g                              38        27  float64
# docosahexaenoic-acid_100g                               78        50  float64
# omega-6-fat_100g                                       188       113  float64
# linoleic-acid_100g                                     149       110  float64
# arachidonic-acid_100g                                    8         7  float64
# gamma-linolenic-acid_100g                               24        11  float64
# dihomo-gamma-linolenic-acid_100g                        23        10  float64
# omega-9-fat_100g                                        21        17  float64
# oleic-acid_100g                                         13        13  float64
# gondoic-acid_100g                                       14         3  float64
# trans-fat_100g                                      143298       428  float64
# cholesterol_100g                                    144090       537  float64
# carbohydrates_100g                                  243588      5416  float64
# sugars_100g                                         244971      4068  float64
# sucrose_100g                                            72        49  float64
# glucose_100g                                            26        15  float64
# fructose_100g                                           38        28  float64
# lactose_100g                                           262        65  float64
# maltose_100g                                             4         4  float64
# maltodextrins_100g                                      11        10  float64
# starch_100g                                            266       138  float64
# polyols_100g                                           414       206  float64
# fiber_100g                                          200886      1016  float64
# proteins_100g                                       259922      2503  float64
# casein_100g                                             27        18  float64
# serum-proteins_100g                                     16        10  float64
# nucleotides_100g                                         9         7  float64
# salt_100g                                           255510      5586  float64
# sodium_100g                                         255463      5291  float64
# alcohol_100g                                          4133       150  float64
# vitamin-a_100g                                      137554      2345  float64
# beta-carotene_100g                                      34        29  float64
# vitamin-d_100g                                        7057       352  float64
# vitamin-e_100g                                        1340       272  float64
# vitamin-k_100g                                         918       307  float64
# vitamin-c_100g                                      140867      1170  float64
# vitamin-b1_100g                                      11154       685  float64
# vitamin-b2_100g                                      10815      1071  float64
# vitamin-pp_100g                                      11729       864  float64
# vitamin-b6_100g                                       6784       605  float64
# vitamin-b9_100g                                       5240       384  float64
# folates_100g                                          3042       260  float64
# vitamin-b12_100g                                      5300       396  float64
# biotin_100g                                            330        95  float64
# pantothenic-acid_100g                                 2483       466  float64
# silica_100g                                             38        24  float64
# bicarbonate_100g                                        81        66  float64
# potassium_100g                                       24748      1187  float64
# chloride_100g                                          158        99  float64
# calcium_100g                                        141050      1123  float64
# phosphorus_100g                                       5845       569  float64
# iron_100g                                           140462      1137  float64
# magnesium_100g                                        6253       606  float64
# zinc_100g                                             3929       415  float64
# copper_100g                                           2106       309  float64
# manganese_100g                                        1620       107  float64
# fluoride_100g                                           79        44  float64
# selenium_100g                                         1168       160  float64
# chromium_100g                                           20        17  float64
# molybdenum_100g                                         11         9  float64
# iodine_100g                                            259       111  float64
# caffeine_100g                                           78        42  float64
# taurine_100g                                            29        17  float64
# ph_100g                                                 49        25  float64
# fruits-vegetables-nuts_100g                           3036       333  float64
# collagen-meat-protein-ratio_100g                       165         6  float64
# cocoa_100g                                             948        84  float64
# carbon-footprint_100g                                  268       202  float64
# nutrition-score-fr_100g                             221210        55  float64
# nutrition-score-uk_100g                             221210        55  float64

# %% [markdown]
# <a name='2'></a>
# # 2. Cleaning: Quantitative features
#
# <a name='2.1'></a>
# ## *_100g* data
#
# Sélection des colonnes

# %%
numeric_cols = data.select_dtypes(include=np.number).columns.tolist()
numeric_cols_100g = numeric_cols.copy()
numeric_cols_100g.remove('additives_n')
numeric_cols_100g.remove('ingredients_from_palm_oil_n')
numeric_cols_100g.remove('ingredients_that_may_be_from_palm_oil_n')

# %%
data_100g = data[numeric_cols_100g]

display(data_100g)
# Out:
#         energy_100g  energy-from-fat_100g  fat_100g  saturated-fat_100g  \
# 0               NaN                   NaN       NaN                 NaN
# 1            2243.0                   NaN     28.57               28.57
# 2            1941.0                   NaN     17.86                0.00
# 3            2540.0                   NaN     57.14                5.36
# 4            1552.0                   NaN      1.43                 NaN
# ...             ...                   ...       ...                 ...
# 320767          NaN                   NaN       NaN                 NaN
# 320768          0.0                   NaN      0.00                0.00
# 320769          NaN                   NaN       NaN                 NaN
# 320770          NaN                   NaN       NaN                 NaN
# 320771       2092.0                   NaN      0.00                 NaN
#
#         caprylic-acid_100g  capric-acid_100g  lauric-acid_100g  \
# 0                      NaN               NaN               NaN
# 1                      NaN               NaN               NaN
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
# ...                    ...               ...               ...
# 320767                 NaN               NaN               NaN
# 320768                 NaN               NaN               NaN
# 320769                 NaN               NaN               NaN
# 320770                 NaN               NaN               NaN
# 320771                 NaN               NaN               NaN
#
#         myristic-acid_100g  palmitic-acid_100g  stearic-acid_100g  ...  \
# 0                      NaN                 NaN                NaN  ...
# 1                      NaN                 NaN                NaN  ...
# 2                      NaN                 NaN                NaN  ...
# 3                      NaN                 NaN                NaN  ...
# 4                      NaN                 NaN                NaN  ...
# ...                    ...                 ...                ...  ...
# 320767                 NaN                 NaN                NaN  ...
# 320768                 NaN                 NaN                NaN  ...
# 320769                 NaN                 NaN                NaN  ...
# 320770                 NaN                 NaN                NaN  ...
# 320771                 NaN                 NaN                NaN  ...
#
#         iodine_100g  caffeine_100g  taurine_100g  ph_100g  \
# 0               NaN            NaN           NaN      NaN
# 1               NaN            NaN           NaN      NaN
# 2               NaN            NaN           NaN      NaN
# 3               NaN            NaN           NaN      NaN
# 4               NaN            NaN           NaN      NaN
# ...             ...            ...           ...      ...
# 320767          NaN            NaN           NaN      NaN
# 320768          NaN            NaN           NaN      NaN
# 320769          NaN            NaN           NaN      NaN
# 320770          NaN            NaN           NaN      NaN
# 320771          NaN            NaN           NaN      NaN
#
#         fruits-vegetables-nuts_100g  collagen-meat-protein-ratio_100g  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 320767                          NaN                               NaN
# 320768                          NaN                               NaN
# 320769                          NaN                               NaN
# 320770                          NaN                               NaN
# 320771                          NaN                               NaN
#
#         cocoa_100g  carbon-footprint_100g  nutrition-score-fr_100g  \
# 0              NaN                    NaN                      NaN
# 1              NaN                    NaN                     14.0
# 2              NaN                    NaN                      0.0
# 3              NaN                    NaN                     12.0
# 4              NaN                    NaN                      NaN
# ...            ...                    ...                      ...
# 320767         NaN                    NaN                      NaN
# 320768         NaN                    NaN                      0.0
# 320769         NaN                    NaN                      NaN
# 320770         NaN                    NaN                      NaN
# 320771         NaN                    NaN                      NaN
#
#         nutrition-score-uk_100g
# 0                           NaN
# 1                          14.0
# 2                           0.0
# 3                          12.0
# 4                           NaN
# ...                         ...
# 320767                      NaN
# 320768                      0.0
# 320769                      NaN
# 320770                      NaN
# 320771                      NaN
#
# [320772 rows x 87 columns]

# %% [markdown]
# <a name='2.1.1'></a>
# ### *_100g* - Data information

# %%
pd.options.mode.chained_assignment = None # default='warn'

data_infos_100g = data_info[data_info['Column'].isin(numeric_cols_100g)]
data_infos_100g['low'] = data[numeric_cols_100g].quantile(0.025)
data_infos_100g['high'] = data[numeric_cols_100g].quantile(0.975)
data_infos_100g['mean'] = data[numeric_cols_100g].mean()

pd.options.mode.chained_assignment = 'warn' # default='warn'

# %%
pd.set_option('display.max_rows', None)
display(data_infos_100g)
pd.set_option('display.max_rows', 10)
# Out:
#                                                             Column  \
# energy_100g                                            energy_100g
# energy-from-fat_100g                          energy-from-fat_100g
# fat_100g                                                  fat_100g
# saturated-fat_100g                              saturated-fat_100g
# caprylic-acid_100g                              caprylic-acid_100g
# capric-acid_100g                                  capric-acid_100g
# lauric-acid_100g                                  lauric-acid_100g
# myristic-acid_100g                              myristic-acid_100g
# palmitic-acid_100g                              palmitic-acid_100g
# stearic-acid_100g                                stearic-acid_100g
# arachidic-acid_100g                            arachidic-acid_100g
# behenic-acid_100g                                behenic-acid_100g
# montanic-acid_100g                              montanic-acid_100g
# monounsaturated-fat_100g                  monounsaturated-fat_100g
# polyunsaturated-fat_100g                  polyunsaturated-fat_100g
# omega-3-fat_100g                                  omega-3-fat_100g
# alpha-linolenic-acid_100g                alpha-linolenic-acid_100g
# eicosapentaenoic-acid_100g              eicosapentaenoic-acid_100g
# docosahexaenoic-acid_100g                docosahexaenoic-acid_100g
# omega-6-fat_100g                                  omega-6-fat_100g
# linoleic-acid_100g                              linoleic-acid_100g
# arachidonic-acid_100g                        arachidonic-acid_100g
# gamma-linolenic-acid_100g                gamma-linolenic-acid_100g
# dihomo-gamma-linolenic-acid_100g  dihomo-gamma-linolenic-acid_100g
# omega-9-fat_100g                                  omega-9-fat_100g
# oleic-acid_100g                                    oleic-acid_100g
# gondoic-acid_100g                                gondoic-acid_100g
# trans-fat_100g                                      trans-fat_100g
# cholesterol_100g                                  cholesterol_100g
# carbohydrates_100g                              carbohydrates_100g
# sugars_100g                                            sugars_100g
# sucrose_100g                                          sucrose_100g
# glucose_100g                                          glucose_100g
# fructose_100g                                        fructose_100g
# lactose_100g                                          lactose_100g
# maltose_100g                                          maltose_100g
# maltodextrins_100g                              maltodextrins_100g
# starch_100g                                            starch_100g
# polyols_100g                                          polyols_100g
# fiber_100g                                              fiber_100g
# proteins_100g                                        proteins_100g
# casein_100g                                            casein_100g
# serum-proteins_100g                            serum-proteins_100g
# nucleotides_100g                                  nucleotides_100g
# salt_100g                                                salt_100g
# sodium_100g                                            sodium_100g
# alcohol_100g                                          alcohol_100g
# vitamin-a_100g                                      vitamin-a_100g
# beta-carotene_100g                              beta-carotene_100g
# vitamin-d_100g                                      vitamin-d_100g
# vitamin-e_100g                                      vitamin-e_100g
# vitamin-k_100g                                      vitamin-k_100g
# vitamin-c_100g                                      vitamin-c_100g
# vitamin-b1_100g                                    vitamin-b1_100g
# vitamin-b2_100g                                    vitamin-b2_100g
# vitamin-pp_100g                                    vitamin-pp_100g
# vitamin-b6_100g                                    vitamin-b6_100g
# vitamin-b9_100g                                    vitamin-b9_100g
# folates_100g                                          folates_100g
# vitamin-b12_100g                                  vitamin-b12_100g
# biotin_100g                                            biotin_100g
# pantothenic-acid_100g                        pantothenic-acid_100g
# silica_100g                                            silica_100g
# bicarbonate_100g                                  bicarbonate_100g
# potassium_100g                                      potassium_100g
# chloride_100g                                        chloride_100g
# calcium_100g                                          calcium_100g
# phosphorus_100g                                    phosphorus_100g
# iron_100g                                                iron_100g
# magnesium_100g                                      magnesium_100g
# zinc_100g                                                zinc_100g
# copper_100g                                            copper_100g
# manganese_100g                                      manganese_100g
# fluoride_100g                                        fluoride_100g
# selenium_100g                                        selenium_100g
# chromium_100g                                        chromium_100g
# molybdenum_100g                                    molybdenum_100g
# iodine_100g                                            iodine_100g
# caffeine_100g                                        caffeine_100g
# taurine_100g                                          taurine_100g
# ph_100g                                                    ph_100g
# fruits-vegetables-nuts_100g            fruits-vegetables-nuts_100g
# collagen-meat-protein-ratio_100g  collagen-meat-protein-ratio_100g
# cocoa_100g                                              cocoa_100g
# carbon-footprint_100g                        carbon-footprint_100g
# nutrition-score-fr_100g                    nutrition-score-fr_100g
# nutrition-score-uk_100g                    nutrition-score-uk_100g
#
#                                   Non-Null Count  n-unique    Dtype  \
# energy_100g                               261113      3997  float64
# energy-from-fat_100g                         857       335  float64
# fat_100g                                  243891      3378  float64
# saturated-fat_100g                        229554      2197  float64
# caprylic-acid_100g                             1         1  float64
# capric-acid_100g                               2         2  float64
# lauric-acid_100g                               4         4  float64
# myristic-acid_100g                             1         1  float64
# palmitic-acid_100g                             1         1  float64
# stearic-acid_100g                              1         1  float64
# arachidic-acid_100g                           24        17  float64
# behenic-acid_100g                             23        15  float64
# montanic-acid_100g                             1         1  float64
# monounsaturated-fat_100g                   22823      1066  float64
# polyunsaturated-fat_100g                   22859       945  float64
# omega-3-fat_100g                             841       225  float64
# alpha-linolenic-acid_100g                    186       112  float64
# eicosapentaenoic-acid_100g                    38        27  float64
# docosahexaenoic-acid_100g                     78        50  float64
# omega-6-fat_100g                             188       113  float64
# linoleic-acid_100g                           149       110  float64
# arachidonic-acid_100g                          8         7  float64
# gamma-linolenic-acid_100g                     24        11  float64
# dihomo-gamma-linolenic-acid_100g              23        10  float64
# omega-9-fat_100g                              21        17  float64
# oleic-acid_100g                               13        13  float64
# gondoic-acid_100g                             14         3  float64
# trans-fat_100g                            143298       428  float64
# cholesterol_100g                          144090       537  float64
# carbohydrates_100g                        243588      5416  float64
# sugars_100g                               244971      4068  float64
# sucrose_100g                                  72        49  float64
# glucose_100g                                  26        15  float64
# fructose_100g                                 38        28  float64
# lactose_100g                                 262        65  float64
# maltose_100g                                   4         4  float64
# maltodextrins_100g                            11        10  float64
# starch_100g                                  266       138  float64
# polyols_100g                                 414       206  float64
# fiber_100g                                200886      1016  float64
# proteins_100g                             259922      2503  float64
# casein_100g                                   27        18  float64
# serum-proteins_100g                           16        10  float64
# nucleotides_100g                               9         7  float64
# salt_100g                                 255510      5586  float64
# sodium_100g                               255463      5291  float64
# alcohol_100g                                4133       150  float64
# vitamin-a_100g                            137554      2345  float64
# beta-carotene_100g                            34        29  float64
# vitamin-d_100g                              7057       352  float64
# vitamin-e_100g                              1340       272  float64
# vitamin-k_100g                               918       307  float64
# vitamin-c_100g                            140867      1170  float64
# vitamin-b1_100g                            11154       685  float64
# vitamin-b2_100g                            10815      1071  float64
# vitamin-pp_100g                            11729       864  float64
# vitamin-b6_100g                             6784       605  float64
# vitamin-b9_100g                             5240       384  float64
# folates_100g                                3042       260  float64
# vitamin-b12_100g                            5300       396  float64
# biotin_100g                                  330        95  float64
# pantothenic-acid_100g                       2483       466  float64
# silica_100g                                   38        24  float64
# bicarbonate_100g                              81        66  float64
# potassium_100g                             24748      1187  float64
# chloride_100g                                158        99  float64
# calcium_100g                              141050      1123  float64
# phosphorus_100g                             5845       569  float64
# iron_100g                                 140462      1137  float64
# magnesium_100g                              6253       606  float64
# zinc_100g                                   3929       415  float64
# copper_100g                                 2106       309  float64
# manganese_100g                              1620       107  float64
# fluoride_100g                                 79        44  float64
# selenium_100g                               1168       160  float64
# chromium_100g                                 20        17  float64
# molybdenum_100g                               11         9  float64
# iodine_100g                                  259       111  float64
# caffeine_100g                                 78        42  float64
# taurine_100g                                  29        17  float64
# ph_100g                                       49        25  float64
# fruits-vegetables-nuts_100g                 3036       333  float64
# collagen-meat-protein-ratio_100g             165         6  float64
# cocoa_100g                                   948        84  float64
# carbon-footprint_100g                        268       202  float64
# nutrition-score-fr_100g                   221210        55  float64
# nutrition-score-uk_100g                   221210        55  float64
#
#                                            low         high         mean
# energy_100g                       0.000000e+00  2690.000000  1141.914605
# energy-from-fat_100g              0.000000e+00  2900.000000   585.501214
# fat_100g                          0.000000e+00    58.000000    12.730379
# saturated-fat_100g                0.000000e+00    23.000000     5.129932
# caprylic-acid_100g                7.400000e+00     7.400000     7.400000
# capric-acid_100g                  5.888000e+00     6.192000     6.040000
# lauric-acid_100g                  3.506375e+00    49.277500    36.136182
# myristic-acid_100g                1.890000e+01    18.900000    18.900000
# palmitic-acid_100g                8.100000e+00     8.100000     8.100000
# stearic-acid_100g                 3.000000e+00     3.000000     3.000000
# arachidic-acid_100g               3.592200e+00    15.285000    10.752667
# behenic-acid_100g                 5.365000e+00    14.435000    10.673913
# montanic-acid_100g                6.100000e+01    61.000000    61.000000
# monounsaturated-fat_100g          0.000000e+00    66.670000    10.425055
# polyunsaturated-fat_100g          0.000000e+00    43.330000     6.312493
# omega-3-fat_100g                  3.700000e-02    16.000000     3.182103
# alpha-linolenic-acid_100g         3.600000e-02    19.125000     2.250285
# eicosapentaenoic-acid_100g        6.017500e-02    23.025000     3.186553
# docosahexaenoic-acid_100g         4.492500e-02     4.800000     1.635462
# omega-6-fat_100g                  1.502500e-01    61.325000    16.229144
# linoleic-acid_100g                2.704000e-01    23.000000     3.823819
# arachidonic-acid_100g             1.347500e-02     0.088600     0.057000
# gamma-linolenic-acid_100g         1.036250e-01     0.201360     0.153842
# dihomo-gamma-linolenic-acid_100g  4.698819e-02     0.079307     0.061567
# omega-9-fat_100g                  1.050000e+00    75.000000    40.192857
# oleic-acid_100g                   2.307000e+00    74.200000    25.123077
# gondoic-acid_100g                 1.000000e-06     0.000003     0.000001
# trans-fat_100g                    0.000000e+00     0.000000     0.073476
# cholesterol_100g                  0.000000e+00     0.107000     0.020071
# carbohydrates_100g                0.000000e+00    90.000000    32.073981
# sugars_100g                       0.000000e+00    75.000000    16.003484
# sucrose_100g                      0.000000e+00    38.462500    11.841667
# glucose_100g                      0.000000e+00    23.075000     2.878846
# fructose_100g                     0.000000e+00   100.075000    25.897368
# lactose_100g                      0.000000e+00    54.665000     6.354084
# maltose_100g                      1.742500e+00    38.960000    24.325000
# maltodextrins_100g                1.500000e+00    25.625000    12.163636
# starch_100g                       0.000000e+00    71.000000    31.925000
# polyols_100g                      0.000000e+00    98.000000    49.790389
# fiber_100g                        0.000000e+00    13.500000     2.862111
# proteins_100g                     0.000000e+00    26.670000     7.075940
# casein_100g                       1.037000e+00    10.375000     4.658148
# serum-proteins_100g               3.000000e-01     5.800000     2.506250
# nucleotides_100g                  1.600000e-02     0.024800     0.021678
# salt_100g                         0.000000e+00     6.985000     2.028624
# sodium_100g                       0.000000e+00     2.750000     0.798815
# alcohol_100g                      0.000000e+00    40.000000     7.838105
# vitamin-a_100g                    0.000000e+00     0.001125     0.000397
# beta-carotene_100g                0.000000e+00     2.938500     0.518715
# vitamin-d_100g                    0.000000e+00     0.000013     0.000008
# vitamin-e_100g                    4.800000e-04     0.057100     0.056705
# vitamin-k_100g                    0.000000e+00     0.001298     0.034219
# vitamin-c_100g                    0.000000e+00     0.054935     0.023367
# vitamin-b1_100g                   0.000000e+00     1.250000     0.325574
# vitamin-b2_100g                   0.000000e+00     1.465517     0.259007
# vitamin-pp_100g                   1.670000e-04     0.033333     0.020303
# vitamin-b6_100g                   2.830000e-05     0.010000     0.023378
# vitamin-b9_100g                   8.400000e-06     0.000266     0.006898
# folates_100g                      0.000000e+00     0.000667     0.205856
# vitamin-b12_100g                  1.147500e-07     0.000030     0.000089
# biotin_100g                       0.000000e+00     3.000000     0.121290
# pantothenic-acid_100g             0.000000e+00     0.059750     0.072138
# silica_100g                       6.943650e-04     0.052235     0.013123
# bicarbonate_100g                  2.270000e-04     0.527000     0.119052
# potassium_100g                    0.000000e+00     1.264600     0.424635
# chloride_100g                     9.000000e-05     0.480750     0.092638
# calcium_100g                      0.000000e+00     0.714000     0.125163
# phosphorus_100g                   8.000000e-03     0.800000     0.617282
# iron_100g                         0.000000e+00     0.009000     0.003652
# magnesium_100g                    1.000000e-03     0.433200     0.534143
# zinc_100g                         1.008000e-04     0.018750     0.007950
# copper_100g                       1.700000e-05     0.002143     0.025794
# manganese_100g                    0.000000e+00     0.005000     0.003014
# fluoride_100g                     2.570000e-06     0.059000     0.012161
# selenium_100g                     7.000000e-07     0.000161     0.003126
# chromium_100g                     7.316500e-06     0.017180     0.001690
# molybdenum_100g                   4.700000e-06     0.002903     0.000401
# iodine_100g                       6.350000e-06     0.002935     0.000427
# caffeine_100g                     0.000000e+00    20.997500     1.594563
# taurine_100g                      4.250000e-03     0.423000     0.145762
# ph_100g                           5.280000e-03     8.140000     6.425698
# fruits-vegetables-nuts_100g       0.000000e+00   100.000000    31.458587
# collagen-meat-protein-ratio_100g  1.200000e+01    25.000000    15.412121
# cocoa_100g                        2.302500e+01    85.000000    49.547785
# carbon-footprint_100g             0.000000e+00  1306.950000   341.700764
# nutrition-score-fr_100g          -6.000000e+00    26.000000     9.165535
# nutrition-score-uk_100g          -6.000000e+00    26.000000     9.058049

# %% [markdown]
# <a name='2.1.2'></a>
# ### *_100g* - Near-empty columns

# %%
print(data.shape)
# Out:
# (320772, 146)

# %%
# Keeping only variables with at least 70% of data available
data = data.drop(data_infos_100g[data_infos_100g['Non-Null Count'] < len(data)*0.7]['Column'], axis=1)

# %%
with pd.option_context('display.max_columns', None):
    display(data.head(1))

print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
#
#   last_modified_t last_modified_datetime        product_name generic_name  \
# 0      1474103893   2016-09-17T09:18:13Z  Farine de blé noir          NaN
#
#   quantity packaging packaging_tags           brands      brands_tags  \
# 0      1kg       NaN            NaN  Ferme t'y R'nao  ferme-t-y-r-nao
#
#   categories categories_tags categories_fr origins origins_tags  \
# 0        NaN             NaN           NaN     NaN          NaN
#
#   manufacturing_places manufacturing_places_tags labels labels_tags labels_fr  \
# 0                  NaN                       NaN    NaN         NaN       NaN
#
#   emb_codes emb_codes_tags first_packaging_code_geo cities cities_tags  \
# 0       NaN            NaN                      NaN    NaN         NaN
#
#   purchase_places stores countries countries_tags countries_fr  \
# 0             NaN    NaN     en:FR      en:france       France
#
#   ingredients_text allergens allergens_fr traces traces_tags traces_fr  \
# 0              NaN       NaN          NaN    NaN         NaN       NaN
#
#   serving_size  additives_n additives additives_tags additives_fr  \
# 0          NaN          NaN       NaN            NaN          NaN
#
#    ingredients_from_palm_oil_n ingredients_from_palm_oil_tags  \
# 0                          NaN                            NaN
#
#    ingredients_that_may_be_from_palm_oil_n  \
# 0                                      NaN
#
#   ingredients_that_may_be_from_palm_oil_tags nutrition_grade_fr pnns_groups_1  \
# 0                                        NaN                NaN           NaN
#
#   pnns_groups_2                                             states  \
# 0           NaN  en:to-be-completed, en:nutrition-facts-to-be-c...
#
#                                          states_tags  \
# 0  en:to-be-completed,en:nutrition-facts-to-be-co...
#
#                                            states_fr main_category  \
# 0  A compléter,Informations nutritionnelles à com...           NaN
#
#   main_category_fr image_url image_small_url  energy_100g  fat_100g  \
# 0              NaN       NaN             NaN          NaN       NaN
#
#    saturated-fat_100g  carbohydrates_100g  sugars_100g  proteins_100g  \
# 0                 NaN                 NaN          NaN            NaN
#
#    salt_100g  sodium_100g
# 0        NaN          NaN
# (320772, 67)

# %% [markdown]
# <a name='2.1.3'></a>
# ### *_100g* - Outliers (w/o `energy_100g`)

# %%
# Removing 'energy_100g' cause scale is different than other _100gs
cols_100g = data.columns[data.columns.isin(numeric_cols_100g)].to_list()
cols_100g_wo_energy = cols_100g.copy()
cols_100g_wo_energy.remove('energy_100g')

# %%
plt.figure(figsize=(15,6))
data.boxplot(column=cols_100g_wo_energy)
# Out:
# <AxesSubplot: >

# %%
# Save NaNs in mask
NaNs_mask = data[cols_100g_wo_energy].copy(deep=True)
NaNs_mask = NaNs_mask.fillna(999999)

# %%
display(NaNs_mask.head())
# Out:
#     fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0  999999.00           999999.00           999999.00    999999.00
# 1      28.57               28.57               64.29        14.29
# 2      17.86                0.00               60.71        17.86
# 3      57.14                5.36               17.86         3.57
# 4       1.43           999999.00               77.14    999999.00
#
#    proteins_100g     salt_100g  sodium_100g
# 0      999999.00  999999.00000   999999.000
# 1           3.57       0.00000        0.000
# 2          17.86       0.63500        0.250
# 3          17.86       1.22428        0.482
# 4           8.57  999999.00000   999999.000

# %%
# Select lines with data < 100
lines_less = NaNs_mask[(NaNs_mask < 0).any(axis=1)].index

# Select lines with data > 100
lines_more = NaNs_mask[((NaNs_mask > 100)
                      & (NaNs_mask != 999999)).any(axis=1)].index

# %%
print(lines_less)
print()
print(lines_more)
# Out:
# Int64Index([8582, 18209, 33781, 115310, 117739, 146284, 150858, 164030, 169119,
#             195761],
#            dtype='int64')
#
# Int64Index([   501,   1435,   3472,   7037,   7983,  11129,  18588,  18845,
#              18848,  18851,
#             ...
#             286482, 287865, 287866, 298059, 303101, 305054, 305114, 313506,
#             315621, 317635],
#            dtype='int64', length=181)

# %%
# Delete lines

print(data.shape)

data = data.drop(lines_less)
data = data.drop(lines_more)

print(data.shape)
# Out:
# (320772, 67)
# (320581, 67)

# %%
plt.figure(figsize=(15,6))
data.boxplot(column=cols_100g_wo_energy)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <a name='2.1.4'></a>
# ### *_100g* - Outliers: `energy_100g`

# %%
# Save NaNs in mask
NaNs_mask = data['energy_100g'].copy(deep=True)
NaNs_mask = NaNs_mask.fillna(999999)

# %%
display(NaNs_mask.head())
# Out:
# 0    999999.0
# 1      2243.0
# 2      1941.0
# 3      2540.0
# 4      1552.0
# Name: energy_100g, dtype: float64

# %%
# Select lines with 'energy' wrong
lines_energy = NaNs_mask[(NaNs_mask < 0)
                      | ((NaNs_mask > 10000) & (NaNs_mask != 999999))].index

# %%
print(lines_energy)
# Out:
# Int64Index([ 20070,  35308,  46967,  66156,  80439, 115777, 119184, 153704,
#             176697, 181668, 212928, 219302, 223318, 249101, 290157, 317171],
#            dtype='int64')

# %%
print(data.shape)

data = data.drop(lines_energy)

print(data.shape)
# Out:
# (320581, 67)
# (320565, 67)

# %%
display(data.head(1))
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
#
#   last_modified_t last_modified_datetime        product_name generic_name  \
# 0      1474103893   2016-09-17T09:18:13Z  Farine de blé noir          NaN
#
#   quantity  ... image_url image_small_url energy_100g fat_100g  \
# 0      1kg  ...       NaN             NaN         NaN      NaN
#
#   saturated-fat_100g carbohydrates_100g sugars_100g proteins_100g salt_100g  \
# 0                NaN                NaN         NaN           NaN       NaN
#
#   sodium_100g
# 0         NaN
#
# [1 rows x 67 columns]

# %% [markdown]
# <a name='2.1.5'></a>
# ### *_100g* - Outliers 2

# %%
data_info_100g = pd.DataFrame({'Null Count': data[cols_100g].isnull().sum(),
                               'Non-Null Count': len(data[cols_100g])-data[cols_100g].isnull().sum(),
                               'n-unique': data[cols_100g].nunique(),
                               'quantile_low': data[cols_100g].quantile(0.025),
                               'quantile_high': data[cols_100g].quantile(0.975),
                               'mean': data[cols_100g].mean()})

# %%
display(data_info_100g)
# Out:
#                     Null Count  Non-Null Count  n-unique  quantile_low  \
# energy_100g              59655          260910      3976           0.0
# fat_100g                 76873          243692      3373           0.0
# saturated-fat_100g       91107          229458      2194           0.0
# carbohydrates_100g       77177          243388      5401           0.0
# sugars_100g              75698          244867      4051           0.0
# proteins_100g            60837          259728      2497           0.0
# salt_100g                65255          255310      5509           0.0
# sodium_100g              65302          255263      5216           0.0
#
#                     quantile_high         mean
# energy_100g            2690.00000  1126.266499
# fat_100g                 58.00000    12.731834
# saturated-fat_100g       23.00000     5.126233
# carbohydrates_100g       90.00000    32.069417
# sugars_100g              75.00000    15.985380
# proteins_100g            26.67000     7.082725
# salt_100g                 6.77418     1.588255
# sodium_100g               2.66700     0.625411

# %%
# Save NaNs in mask
NaNs_mask = data[cols_100g].copy(deep=True)
NaNs_mask = NaNs_mask.fillna(999999)

# %%
display(NaNs_mask.head(3))
# Out:
#    energy_100g   fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 0     999999.0  999999.00           999999.00           999999.00
# 1       2243.0      28.57               28.57               64.29
# 2       1941.0      17.86                0.00               60.71
#
#    sugars_100g  proteins_100g   salt_100g  sodium_100g
# 0    999999.00      999999.00  999999.000    999999.00
# 1        14.29           3.57       0.000         0.00
# 2        17.86          17.86       0.635         0.25

# %%
# Select outliers with quantiles > 0.025 & < 0.975

outliers_high = NaNs_mask[((NaNs_mask > data_info_100g['quantile_high'])
                         & (NaNs_mask != 999999)).any(axis=1)].index

outliers_low = NaNs_mask[(NaNs_mask < data_info_100g['quantile_low']).any(axis=1)].index

# %%
print(outliers_high)
print()
print(outliers_low)
# Out:
# Int64Index([     1,      9,     14,     16,     17,     25,     30,     32,
#                 36,     38,
#             ...
#             320619, 320637, 320649, 320656, 320669, 320681, 320702, 320717,
#             320732, 320741],
#            dtype='int64', length=31600)
#
# Int64Index([], dtype='int64')

# %%
# Delete outliers

print(data.shape)

data = data.drop(outliers_high)
data = data.drop(outliers_low)

print(data.shape)
# Out:
# (320565, 67)
# (288965, 67)

# %% [markdown]
# <a name='2.1.6'></a>
# ### *_100g* - NaNs
#
# Remplacement des valeurs manquantes avec :
# - La moyenne <--
# - La médianne
# - Régression linéaire
# - 0
#
#
# moyenne par pnns group (type de produit)

# %%
data[cols_100g] = data[cols_100g].fillna(data[cols_100g].mean())

# %%
display(data[cols_100g].head(3))
# Out:
#    energy_100g   fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 0  1031.871034  10.771763            4.240857           31.049571
# 2  1941.000000  17.860000            0.000000           60.710000
# 3  2540.000000  57.140000            5.360000           17.860000
#
#    sugars_100g  proteins_100g  salt_100g  sodium_100g
# 0    14.112095       6.700509   0.871093      0.34302
# 2    17.860000      17.860000   0.635000      0.25000
# 3     3.570000      17.860000   1.224280      0.48200

# %%
display(data.head(3))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
# 2  0000000004559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  0000000016087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
#
#   last_modified_t last_modified_datetime            product_name generic_name  \
# 0      1474103893   2016-09-17T09:18:13Z      Farine de blé noir          NaN
# 2      1489069957   2017-03-09T14:32:37Z                 Peanuts          NaN
# 3      1489055731   2017-03-09T10:35:31Z  Organic Salted Nut Mix          NaN
#
#   quantity  ... image_url image_small_url  energy_100g   fat_100g  \
# 0      1kg  ...       NaN             NaN  1031.871034  10.771763
# 2      NaN  ...       NaN             NaN  1941.000000  17.860000
# 3      NaN  ...       NaN             NaN  2540.000000  57.140000
#
#   saturated-fat_100g carbohydrates_100g sugars_100g proteins_100g salt_100g  \
# 0           4.240857          31.049571   14.112095      6.700509  0.871093
# 2           0.000000          60.710000   17.860000     17.860000  0.635000
# 3           5.360000          17.860000    3.570000     17.860000  1.224280
#
#   sodium_100g
# 0     0.34302
# 2     0.25000
# 3     0.48200
#
# [3 rows x 67 columns]
# (288965, 67)

# %% [markdown]
# <a name='3'></a>
# # 3. Cleaning: Qualitative features

# %%
qual_cols = data.select_dtypes(include='object').columns.tolist()

# %% [markdown]
# <a name='3.1'></a>
# ## 1) Qualitative features - Data information

# %%
data_info_qual = pd.DataFrame({'Null Count': data[qual_cols].isnull().sum(),
                               'Non-Null Count': len(data[qual_cols])-data[qual_cols].isnull().sum(),
                               'n-unique': data[qual_cols].nunique(),
                               'Dtype': data[qual_cols].dtypes})

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_info_qual)
# Out:
#                                             Null Count  Non-Null Count  \
# code                                                23          288942
# url                                                 23          288942
# creator                                              2          288963
# created_t                                            3          288962
# created_datetime                                     9          288956
# last_modified_t                                      0          288965
# last_modified_datetime                               0          288965
# product_name                                     17373          271592
# generic_name                                    240089           48876
# quantity                                        190862           98103
# packaging                                       215656           73309
# packaging_tags                                  215655           73310
# brands                                           27701          261264
# brands_tags                                      27707          261258
# categories                                      210653           78312
# categories_tags                                 210674           78291
# categories_fr                                   210652           78313
# origins                                         268608           20357
# origins_tags                                    268643           20322
# manufacturing_places                            255151           33814
# manufacturing_places_tags                       255157           33808
# labels                                          246082           42883
# labels_tags                                     246009           42956
# labels_fr                                       245987           42978
# emb_codes                                       261865           27100
# emb_codes_tags                                  261868           27097
# first_packaging_code_geo                        271452           17513
# cities                                          288942              23
# cities_tags                                     270049           18916
# purchase_places                                 235079           53886
# stores                                          240989           47976
# countries                                          270          288695
# countries_tags                                     270          288695
# countries_fr                                       270          288695
# ingredients_text                                 68482          220483
# allergens                                       262516           26449
# allergens_fr                                    288946              19
# traces                                          266324           22641
# traces_tags                                     266348           22617
# traces_fr                                       266325           22640
# serving_size                                    102833          186132
# additives                                        68538          220427
# additives_tags                                  149785          139180
# additives_fr                                    149785          139180
# ingredients_from_palm_oil_tags                  284507            4458
# ingredients_that_may_be_from_palm_oil_tags      277999           10966
# nutrition_grade_fr                               89749          199216
# pnns_groups_1                                   203999           84966
# pnns_groups_2                                   201024           87941
# states                                              46          288919
# states_tags                                         46          288919
# states_fr                                           46          288919
# main_category                                   210697           78268
# main_category_fr                                210697           78268
# image_url                                       217865           71100
# image_small_url                                 217865           71100
#
#                                             n-unique   Dtype
# code                                          288942  object
# url                                           288942  object
# creator                                         3446  object
# created_t                                     179554  object
# created_datetime                              179555  object
# last_modified_t                               171357  object
# last_modified_datetime                        171357  object
# product_name                                  200789  object
# generic_name                                   35992  object
# quantity                                       13277  object
# packaging                                      13623  object
# packaging_tags                                 11300  object
# brands                                         54346  object
# brands_tags                                    46457  object
# categories                                     34755  object
# categories_tags                                20010  object
# categories_fr                                  20020  object
# origins                                         4522  object
# origins_tags                                    4087  object
# manufacturing_places                            6826  object
# manufacturing_places_tags                       6284  object
# labels                                         16951  object
# labels_tags                                    12801  object
# labels_fr                                      12803  object
# emb_codes                                       7914  object
# emb_codes_tags                                  7638  object
# first_packaging_code_geo                        1550  object
# cities                                             3  object
# cities_tags                                     2450  object
# purchase_places                                 4838  object
# stores                                          3084  object
# countries                                       1365  object
# countries_tags                                   692  object
# countries_fr                                     689  object
# ingredients_text                              184139  object
# allergens                                      12476  object
# allergens_fr                                      19  object
# traces                                          7885  object
# traces_tags                                     3401  object
# traces_fr                                       3407  object
# serving_size                                   23303  object
# additives                                     176119  object
# additives_tags                                 37912  object
# additives_fr                                   37912  object
# ingredients_from_palm_oil_tags                    14  object
# ingredients_that_may_be_from_palm_oil_tags       153  object
# nutrition_grade_fr                                 5  object
# pnns_groups_1                                     14  object
# pnns_groups_2                                     42  object
# states                                          1014  object
# states_tags                                     1014  object
# states_fr                                       1014  object
# main_category                                   3327  object
# main_category_fr                                3327  object
# image_url                                      71100  object
# image_small_url                                71100  object

# %% [markdown]
# <a name='3.2'></a>
# ## 2) Near-empty columns

# %%
print(data.shape)
# Out:
# (288965, 67)

# %%
data = data.drop(data_info_qual[data_info_qual['Non-Null Count'] < len(data)*0.65].index, axis=1)

# %%
with pd.option_context('display.max_columns', None):
    display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
#
#   last_modified_t last_modified_datetime        product_name           brands  \
# 0      1474103893   2016-09-17T09:18:13Z  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags countries countries_tags countries_fr ingredients_text  \
# 0  ferme-t-y-r-nao     en:FR      en:france       France              NaN
#
#    additives_n additives  ingredients_from_palm_oil_n  \
# 0          NaN       NaN                          NaN
#
#    ingredients_that_may_be_from_palm_oil_n nutrition_grade_fr  \
# 0                                      NaN                NaN
#
#                                               states  \
# 0  en:to-be-completed, en:nutrition-facts-to-be-c...
#
#                                          states_tags  \
# 0  en:to-be-completed,en:nutrition-facts-to-be-co...
#
#                                            states_fr  energy_100g   fat_100g  \
# 0  A compléter,Informations nutritionnelles à com...  1031.871034  10.771763
#
#    saturated-fat_100g  carbohydrates_100g  sugars_100g  proteins_100g  \
# 0            4.240857           31.049571    14.112095       6.700509
#
#    salt_100g  sodium_100g
# 0   0.871093      0.34302
# (288965, 30)

# %% [markdown]
# <a name='3.3'></a>
# ## 3) `code`

# %%
data['code'] = regularize(data['code'])
# Out:
# Before regularization: 288942
# After regularization: 288942

# %%
# Delete lines without 'code'
print(data.shape)
data = data.drop(data[data['code'].isnull()].index)
print(data.shape)
# Out:
# (288965, 30)
# (288942, 30)

# %%
# Check for duplicates
display(data[data.duplicated(subset='code', keep=False)].sort_values(by='code', ascending=True))

# Delete duplicates, keep most recent entry ('last') # ?
print(data.shape)
data = data.drop(data[data.duplicated(subset='code', keep='last')].index)
print(data.shape)
# Out:
# Empty DataFrame
# Columns: [code, url, creator, created_t, created_datetime, last_modified_t, last_modified_datetime, product_name, brands, brands_tags, countries, countries_tags, countries_fr, ingredients_text, additives_n, additives, ingredients_from_palm_oil_n, ingredients_that_may_be_from_palm_oil_n, nutrition_grade_fr, states, states_tags, states_fr, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, proteins_100g, salt_100g, sodium_100g]
# Index: []
#
# [0 rows x 30 columns]
# (288942, 30)
# (288942, 30)

# %%
# Check if they are weird codes

test_for_letters = data[data['code'].str.isdigit()]

# %%
print(test_for_letters.shape == data.shape) # All codes are digits only
# Out:
# True

# %% [markdown]
# I wanted to convert `code` to numeric dtype to check for potential errors but it's not possible since the numbers would be too big.

# %% [markdown]
# <a name='3.4'></a>
# ## 4) NaNs

# %%
qual_cols = data.columns[data.columns.isin(qual_cols)].to_list()
print(qual_cols)
# Out:
# ['code', 'url', 'creator', 'created_t', 'created_datetime', 'last_modified_t', 'last_modified_datetime', 'product_name', 'brands', 'brands_tags', 'countries', 'countries_tags', 'countries_fr', 'ingredients_text', 'additives', 'nutrition_grade_fr', 'states', 'states_tags', 'states_fr']

# %%
# Replace NaNs by 'Not Specified'
data[qual_cols] = data[qual_cols].fillna('not specified')

# %%
data_info_qual = pd.DataFrame({'Column': data[qual_cols].columns,
                               'Not Specified': (data[qual_cols] == 'not specified').sum(),
                               'Non-Null Count': len(data[qual_cols])-data[qual_cols].isnull().sum(),
                               'n-unique': data[qual_cols].nunique(),
                               'Dtype': data[qual_cols].dtypes})

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data_info_qual)
# Out:
#                                         Column  Not Specified  Non-Null Count  \
# code                                      code              0          288942
# url                                        url              0          288942
# creator                                creator              2          288942
# created_t                            created_t              0          288942
# created_datetime              created_datetime              1          288942
# last_modified_t                last_modified_t              0          288942
# last_modified_datetime  last_modified_datetime              0          288942
# product_name                      product_name          17373          288942
# brands                                  brands          27678          288942
# brands_tags                        brands_tags          27684          288942
# countries                            countries            270          288942
# countries_tags                  countries_tags            270          288942
# countries_fr                      countries_fr            270          288942
# ingredients_text              ingredients_text          68482          288942
# additives                            additives          68515          288942
# nutrition_grade_fr          nutrition_grade_fr          89726          288942
# states                                  states             23          288942
# states_tags                        states_tags             23          288942
# states_fr                            states_fr             23          288942
#
#                         n-unique   Dtype
# code                      288942  object
# url                       288942  object
# creator                     3445  object
# created_t                 179543  object
# created_datetime          179543  object
# last_modified_t           171353  object
# last_modified_datetime    171353  object
# product_name              200786  object
# brands                     54347  object
# brands_tags                46458  object
# countries                   1360  object
# countries_tags               687  object
# countries_fr                 685  object
# ingredients_text          184135  object
# additives                 176120  object
# nutrition_grade_fr             6  object
# states                      1015  object
# states_tags                 1015  object
# states_fr                   1015  object

# %% [markdown]
# <a name='3.5'></a>
# ## 5) Variables
#
# <a name = 'date_created'></a>
# ### `date_created`

# %%
display(data.head(1))
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
#
#   last_modified_t last_modified_datetime        product_name           brands  \
# 0      1474103893   2016-09-17T09:18:13Z  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags  ...                                        states_tags  \
# 0  ferme-t-y-r-nao  ...  en:to-be-completed,en:nutrition-facts-to-be-co...
#
#                                            states_fr  energy_100g   fat_100g  \
# 0  A compléter,Informations nutritionnelles à com...  1031.871034  10.771763
#
#    saturated-fat_100g carbohydrates_100g  sugars_100g  proteins_100g  \
# 0            4.240857          31.049571    14.112095       6.700509
#
#   salt_100g sodium_100g
# 0  0.871093     0.34302
#
# [1 rows x 30 columns]

# %%
print(data.loc[0, 'created_t'])
print(data.loc[0, 'created_datetime'])
# Out:
# 1474103866
# 2016-09-17T09:17:46Z

# %%
data['date_created'] = pd.to_datetime(data['created_t'], unit='s')

# %%
print(data.loc[0, 'date_created'])
# Out:
# 2016-09-17 09:17:46

# %%
data = data.drop(['created_t',
                  'created_datetime'], axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator last_modified_t last_modified_datetime  \
# 0  openfoodfacts-contributors      1474103893   2016-09-17T09:18:13Z
#
#          product_name           brands      brands_tags countries  \
# 0  Farine de blé noir  Ferme t'y R'nao  ferme-t-y-r-nao     en:FR
#
#   countries_tags  ...                                          states_fr  \
# 0      en:france  ...  A compléter,Informations nutritionnelles à com...
#
#    energy_100g   fat_100g saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0  1031.871034  10.771763           4.240857           31.049571    14.112095
#
#   proteins_100g salt_100g sodium_100g        date_created
# 0      6.700509  0.871093     0.34302 2016-09-17 09:17:46
#
# [1 rows x 29 columns]
# (288942, 29)

# %% [markdown]
# Deleting outlier

# %%
plt.plot(data['date_created'].sort_values(ascending=True), range(len(data)), '.')

# %%
data = data[data['date_created'] > '2010-01-01 00:00:00']

# %%
plt.plot(data['date_created'].sort_values(ascending=True), range(len(data)), '.')

# %% [markdown]
# <a name='last_modified'></a>
# ### `last_modified`

# %%
display(data.head(1))
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator last_modified_t last_modified_datetime  \
# 0  openfoodfacts-contributors      1474103893   2016-09-17T09:18:13Z
#
#          product_name           brands      brands_tags countries  \
# 0  Farine de blé noir  Ferme t'y R'nao  ferme-t-y-r-nao     en:FR
#
#   countries_tags  ...                                          states_fr  \
# 0      en:france  ...  A compléter,Informations nutritionnelles à com...
#
#    energy_100g   fat_100g saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 0  1031.871034  10.771763           4.240857           31.049571    14.112095
#
#   proteins_100g salt_100g sodium_100g        date_created
# 0      6.700509  0.871093     0.34302 2016-09-17 09:17:46
#
# [1 rows x 29 columns]

# %%
print(data.loc[0, 'last_modified_t'])
print(data.loc[0, 'last_modified_datetime'])
# Out:
# 1474103893
# 2016-09-17T09:18:13Z

# %%
data['last_modified'] = pd.to_datetime(data['last_modified_t'], unit='s')

# %%
print(data.loc[0, 'date_created'])
# Out:
# 2016-09-17 09:17:46

# %%
data = data.drop(['last_modified_t',
                  'last_modified_datetime'], axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name           brands  \
# 0  openfoodfacts-contributors  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags countries countries_tags countries_fr ingredients_text  \
# 0  ferme-t-y-r-nao     en:FR      en:france       France    not specified
#
#    ...  energy_100g   fat_100g  saturated-fat_100g  carbohydrates_100g  \
# 0  ...  1031.871034  10.771763            4.240857           31.049571
#
#   sugars_100g proteins_100g salt_100g sodium_100g        date_created  \
# 0   14.112095      6.700509  0.871093     0.34302 2016-09-17 09:17:46
#
#         last_modified
# 0 2016-09-17 09:18:13
#
# [1 rows x 28 columns]
# (288941, 28)

# %%
#print(cleaned_data_qual.info())

# %% [markdown]
# <a name='countries_tags'></a>
# ### `countries_tags`
#
# Get more informations about the countries

# %%
data['countries_tags'] = regularize(data['countries_tags'])
# Out:
# Before regularization: 687
# After regularization: 687

# %%
countries = data['countries_tags'].str.split(pat=',', n=3, expand=True)

# %%
display(countries.head(1))
print(countries.shape)
# Out:
#            0     1     2     3
# 0  en:france  None  None  None
# (288941, 4)

# %%
countries = countries.drop(3, axis=1)
countries = countries.rename(columns={0: 'country_1',
                                      1: 'country_2',
                                      2: 'country_3'})
countries = countries.fillna('not specified')

# %%
display(countries.head(1))
# Out:
#    country_1      country_2      country_3
# 0  en:france  not specified  not specified

# %%
data = data.join(countries, how='left')

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name           brands  \
# 0  openfoodfacts-contributors  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags countries countries_tags countries_fr ingredients_text  \
# 0  ferme-t-y-r-nao     en:FR      en:france       France    not specified
#
#    ...  carbohydrates_100g sugars_100g  proteins_100g  salt_100g sodium_100g  \
# 0  ...           31.049571   14.112095       6.700509   0.871093     0.34302
#
#          date_created       last_modified  country_1      country_2  \
# 0 2016-09-17 09:17:46 2016-09-17 09:18:13  en:france  not specified
#
#        country_3
# 0  not specified
#
# [1 rows x 31 columns]
# (288941, 31)

# %%
data = data.drop(['countries',
                  'countries_tags',
                  'countries_fr'], axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name           brands  \
# 0  openfoodfacts-contributors  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags ingredients_text  additives_n      additives  \
# 0  ferme-t-y-r-nao    not specified          NaN  not specified
#
#    ingredients_from_palm_oil_n  ...  carbohydrates_100g sugars_100g  \
# 0                          NaN  ...           31.049571   14.112095
#
#   proteins_100g salt_100g sodium_100g        date_created       last_modified  \
# 0      6.700509  0.871093     0.34302 2016-09-17 09:17:46 2016-09-17 09:18:13
#
#    country_1      country_2      country_3
# 0  en:france  not specified  not specified
#
# [1 rows x 28 columns]
# (288941, 28)

# %% [markdown]
# <a name='brands_tags'></a>
# ### `brands_tags`

# %%
data['brands_tags'] = regularize(data['brands_tags'])
# Out:
# Before regularization: 46458
# After regularization: 46458

# %%
brands = data['brands_tags'].str.split(pat=',', n=3, expand=True)

# %%
brands[brands.columns[0]].value_counts()
# Out:
# not specified        27684
# carrefour             3332
# auchan                2555
# meijer                2310
# u                     1994
#                      ...
# ferme-de-l-abbaye        1
# axa                      1
# punch-daddy              1
# lentilky                 1
# parkside-bakery          1
# Name: 0, Length: 39678, dtype: int64

# %%
brands[brands.columns[1]].value_counts()
# Out:
# propiedad-de               2305
# marque-repere              1938
# unilever                    707
# whole-foods-market-inc      602
# target-stores               595
#                            ...
# les-vergers-du-chouquet       1
# gault-millau                  1
# kloster-gold                  1
# grossmann                     1
# royal-wine-corporation        1
# Name: 1, Length: 5368, dtype: int64

# %%
brands[brands.columns[2]].value_counts()
# Out:
# groupe-carrefour                  229
# groupe-casino                     198
# les-mousquetaires                 184
# mercadona-s-a                     170
# auchan-production                 166
#                                  ...
# in-fi-coffee                        1
# idahoan-foods-llc                   1
# mercajara-s-l                       1
# expafruit-s-a                       1
# s-a-t-no-747-hermanos-carrasco      1
# Name: 2, Length: 1125, dtype: int64

# %%
display(brands.head(1))
print(brands.shape)
# Out:
#                  0     1     2     3
# 0  ferme-t-y-r-nao  None  None  None
# (288941, 4)

# %%
brands = brands.drop(3, axis=1)
brands = brands.rename(columns={0: 'brand_1',
                                1: 'brand_2',
                                2: 'brand_3'})
brands = brands.fillna('not specified')

# %%
display(brands.head(1))
# Out:
#            brand_1        brand_2        brand_3
# 0  ferme-t-y-r-nao  not specified  not specified

# %%
data = data.join(brands, how='left')

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name           brands  \
# 0  openfoodfacts-contributors  Farine de blé noir  Ferme t'y R'nao
#
#        brands_tags ingredients_text  additives_n      additives  \
# 0  ferme-t-y-r-nao    not specified          NaN  not specified
#
#    ingredients_from_palm_oil_n  ...  salt_100g sodium_100g  \
# 0                          NaN  ...   0.871093     0.34302
#
#          date_created       last_modified  country_1      country_2  \
# 0 2016-09-17 09:17:46 2016-09-17 09:18:13  en:france  not specified
#
#        country_3          brand_1        brand_2        brand_3
# 0  not specified  ferme-t-y-r-nao  not specified  not specified
#
# [1 rows x 31 columns]
# (288941, 31)

# %%
data = data.drop(['brands',
                  'brands_tags'], axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name ingredients_text  \
# 0  openfoodfacts-contributors  Farine de blé noir    not specified
#
#    additives_n      additives  ingredients_from_palm_oil_n  \
# 0          NaN  not specified                          NaN
#
#    ingredients_that_may_be_from_palm_oil_n nutrition_grade_fr  ... salt_100g  \
# 0                                      NaN      not specified  ...  0.871093
#
#   sodium_100g        date_created       last_modified  country_1  \
# 0     0.34302 2016-09-17 09:17:46 2016-09-17 09:18:13  en:france
#
#        country_2      country_3          brand_1        brand_2        brand_3
# 0  not specified  not specified  ferme-t-y-r-nao  not specified  not specified
#
# [1 rows x 29 columns]
# (288941, 29)

# %% [markdown]
# <a name='states'></a>
# ### `states`
# States data is not interesting so we're just deleting it

# %%
data = data.drop(['states',
                  'states_tags',
                  'states_fr'], axis=1)

# %%
print(data.shape)
# Out:
# (288941, 26)

# %% [markdown]
# <a name='additives'></a>
# ### `additives`

# %%
data['additives'] = regularize(data['additives'])
# Out:
# Before regularization: 176120
# After regularization: 176120

# %%
additives = data['additives'].str.split(pat=' \[ ', n=11, expand=True)

# %%
additives[additives.columns[10]].value_counts()
# Out:
# salt -> en:salt  ]                                                                                   3747
# mononitrate -> en:mononitrate  ]                                                                     3085
# sugar -> en:sugar  ]                                                                                 2419
# oil -> en:oil  ]                                                                                     2222
# iron -> en:iron  ]                                                                                   2168
#                                                                                                      ...
# pasteurized-light-cream -> en:pasteurized-light-cream  ]                                                1
# fumee-liquide -> fr:fumee-liquide  ]                                                                    1
# powdered-onion-and-other-all-natural-spices -> en:powdered-onion-and-other-all-natural-spices  ]        1
# jus-de-pomme-de-concentre -> fr:jus-de-pomme-de-concentre  ]                                            1
# disodium-edta-tomato-sauce -> en:disodium-edta-tomato-sauce  ]                                          1
# Name: 10, Length: 24896, dtype: int64

# %%
display(additives.head(2))
print(additives.shape)
# Out:
#               0                          1   \
# 0  not specified                       None
# 2                 peanuts -> en:peanuts  ]
#
#                                   2                      3   \
# 0                               None                   None
# 2  wheat-flour -> en:wheat-flour  ]   flour -> en:flour  ]
#
#                       4                                5   \
# 0                   None                             None
# 2  sugar -> en:sugar  ]   rice-flour -> en:rice-flour  ]
#
#                       6                                        7   \
# 0                   None                                     None
# 2  flour -> en:flour  ]   tapioca-starch -> en:tapioca-starch  ]
#
#                         8                    9   \
# 0                     None                 None
# 2  starch -> en:starch  ]   salt -> en:salt  ]
#
#                               10  \
# 0                           None
# 2  leavening -> en:leavening  ]
#
#                                                   11
# 0                                               None
# 2  ammonium-bicarbonate -> en:ammonium-bicarbonat...
# (288941, 12)

# %%
additives = additives.drop([0, 11], axis=1)
additives = additives.rename({1: 'additive_1',
                              2: 'additive_2',
                              3: 'additive_3',
                              4: 'additive_4',
                              5: 'additive_5',
                              6: 'additive_6',
                              7: 'additive_7',
                              8: 'additive_8',
                              9: 'additive_9',
                              10: 'additive_10'}, axis=1)
additives = additives.fillna('not specified')

# %%
for j in additives.columns:
    additives[j] = [additives[j][i].split(' ->')[0] for i in additives[j].index]

# %%
display(additives.head(2))
print(additives.shape)
# Out:
#       additive_1     additive_2     additive_3     additive_4     additive_5  \
# 0  not specified  not specified  not specified  not specified  not specified
# 2        peanuts    wheat-flour          flour          sugar     rice-flour
#
#       additive_6      additive_7     additive_8     additive_9    additive_10
# 0  not specified   not specified  not specified  not specified  not specified
# 2          flour  tapioca-starch         starch           salt      leavening
# (288941, 10)

# %%
data = data.join(additives, how='left')

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name ingredients_text  \
# 0  openfoodfacts-contributors  Farine de blé noir    not specified
#
#    additives_n      additives  ingredients_from_palm_oil_n  \
# 0          NaN  not specified                          NaN
#
#    ingredients_that_may_be_from_palm_oil_n nutrition_grade_fr  ...  \
# 0                                      NaN      not specified  ...
#
#       additive_1     additive_2     additive_3     additive_4     additive_5  \
# 0  not specified  not specified  not specified  not specified  not specified
#
#       additive_6     additive_7     additive_8     additive_9    additive_10
# 0  not specified  not specified  not specified  not specified  not specified
#
# [1 rows x 36 columns]
# (288941, 36)

# %%
data = data.drop(['additives'], axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name ingredients_text  \
# 0  openfoodfacts-contributors  Farine de blé noir    not specified
#
#    additives_n  ingredients_from_palm_oil_n  \
# 0          NaN                          NaN
#
#    ingredients_that_may_be_from_palm_oil_n nutrition_grade_fr  energy_100g  \
# 0                                      NaN      not specified  1031.871034
#
#    ...     additive_1     additive_2     additive_3     additive_4  \
# 0  ...  not specified  not specified  not specified  not specified
#
#       additive_5     additive_6     additive_7     additive_8     additive_9  \
# 0  not specified  not specified  not specified  not specified  not specified
#
#      additive_10
# 0  not specified
#
# [1 rows x 35 columns]
# (288941, 35)

# %% [markdown]
# <a name='ingredients_text'></a>
# ### `ingredients_text`
#
# Basically same as `additive`, so deleting

# %%
data['ingredients_text'] = regularize(data['ingredients_text'])
# Out:
# Before regularization: 184134
# After regularization: 183247

# %%
data = data.drop('ingredients_text', axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name  additives_n  \
# 0  openfoodfacts-contributors  Farine de blé noir          NaN
#
#    ingredients_from_palm_oil_n  ingredients_that_may_be_from_palm_oil_n  \
# 0                          NaN                                      NaN
#
#   nutrition_grade_fr  energy_100g   fat_100g  ...     additive_1  \
# 0      not specified  1031.871034  10.771763  ...  not specified
#
#       additive_2     additive_3     additive_4     additive_5     additive_6  \
# 0  not specified  not specified  not specified  not specified  not specified
#
#       additive_7     additive_8     additive_9    additive_10
# 0  not specified  not specified  not specified  not specified
#
# [1 rows x 34 columns]
# (288941, 34)

# %% [markdown]
# <a name='nutrition_grade_fr'></a>
# ### `nutrition_grade_fr`

# %%
data['nutrition_grade_fr'] = regularize(data['nutrition_grade_fr'])
# Out:
# Before regularization: 6
# After regularization: 6

# %%
[print(i, ': ', (data[data['nutrition_grade_fr'] == i]['nutrition_grade_fr']).count())
 for i in data['nutrition_grade_fr'].unique()]
# Out:
# not specified :  89726
# b :  33840
# d :  52019
# c :  42531
# a :  35169
# e :  35656
# [None, None, None, None, None, None]

# %%
print(data['nutrition_grade_fr'].unique())
# Out:
# ['not specified' 'b' 'd' 'c' 'a' 'e']

# %% [markdown]
# <a name='url'></a>
# ### `url`

# %%
data['url'] = regularize(data['url'])
# Out:
# Before regularization: 288941
# After regularization: 288941

# %%
#Check for duplicates - no duplicates / also nunique == max
display(data[data.duplicated(subset='url', keep=False)].sort_values(by='url', ascending=True))
# Out:
# Empty DataFrame
# Columns: [code, url, creator, product_name, additives_n, ingredients_from_palm_oil_n, ingredients_that_may_be_from_palm_oil_n, nutrition_grade_fr, energy_100g, fat_100g, saturated-fat_100g, carbohydrates_100g, sugars_100g, proteins_100g, salt_100g, sodium_100g, date_created, last_modified, country_1, country_2, country_3, brand_1, brand_2, brand_3, additive_1, additive_2, additive_3, additive_4, additive_5, additive_6, additive_7, additive_8, additive_9, additive_10]
# Index: []
#
# [0 rows x 34 columns]

# %%
data['url'].unique()
# Out:
# array(['http://world-fr.openfoodfacts.org/produit/0000000003087/farine-de-ble-noir-ferme-t-y-r-nao',
#        'http://world-fr.openfoodfacts.org/produit/0000000004559/peanuts-torn-glasser',
#        'http://world-fr.openfoodfacts.org/produit/0000000016087/organic-salted-nut-mix-grizzlies',
#        ...,
#        'http://world-fr.openfoodfacts.org/produit/9970229501521/%e4%b9%90%e5%90%a7%e6%b3%a1%e8%8f%9c%e5%91%b3%e8%96%af%e7%89%87-%e4%b9%90%e5%90%a7',
#        'http://world-fr.openfoodfacts.org/produit/9980282863788/tomates-aux-vermicelles-knorr',
#        'http://world-fr.openfoodfacts.org/produit/999990026839/sugar-free-drink-mix-peach-tea-market-pantry'],
#       dtype=object)

# %%
data['url'].nunique()
# Out:
# 288941

# %%
data[[i.startswith('http://world-fr.openfoodfacts.org/produit/')
      for i in data['url']]].shape
# Out:
# (288941, 34)

# %%
data[[i.startswith('http://world-fr.openfoodfacts.org/produi/')
      for i in data['url']]].shape
# Out:
# (0, 34)

# %% [markdown]
# No formatting problems in URLs
#
# <a name='creator'></a>
# ### `creator`

# %%
data['creator'] = regularize(data['creator'])
# Out:
# Before regularization: 3445
# After regularization: 3445

# %%
data['creator'].unique()
# Out:
# array(['openfoodfacts-contributors', 'usda-ndb-import', 'date-limite-app',
#        ..., 'patrico', 'zmorlock', 'robopetr'], dtype=object)

# %% [markdown]
# <a name='product_name'></a>
# ### `product_name`

# %%
data['product_name'] = regularize(data['product_name'])
# Out:
# Before regularization: 200785
# After regularization: 194489

# %%
data['product_name'].unique()
# Out:
# array(['farine de blé noir', 'peanuts', 'organic salted nut mix', ...,
#        'mint melange tea a blend of peppermint, lemon grass and spearmint',
#        '乐吧泡菜味薯片', 'tomates aux vermicelles '], dtype=object)

# %% [markdown]
# <a name='additives_n'></a>
# ### `additives_n`
#
# Useless so deleting

# %%
data = data.drop('additives_n', axis=1)

# %%
display(data.head(1))
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name  \
# 0  openfoodfacts-contributors  farine de blé noir
#
#    ingredients_from_palm_oil_n  ingredients_that_may_be_from_palm_oil_n  \
# 0                          NaN                                      NaN
#
#   nutrition_grade_fr  energy_100g   fat_100g  saturated-fat_100g  ...  \
# 0      not specified  1031.871034  10.771763            4.240857  ...
#
#       additive_1     additive_2     additive_3     additive_4     additive_5  \
# 0  not specified  not specified  not specified  not specified  not specified
#
#       additive_6     additive_7     additive_8     additive_9    additive_10
# 0  not specified  not specified  not specified  not specified  not specified
#
# [1 rows x 33 columns]
# (288941, 33)

# %% [markdown]
# <a name='ingredients_from_palm_oil_n'></a>
# ### `ingredients_from_palm_oil_n`

# %%
data['ingredients_from_palm_oil_n'] = data['ingredients_from_palm_oil_n'].fillna('not specified')

# %%
data['ingredients_from_palm_oil_n'].nunique()
# Out:
# 4

# %%
data['ingredients_from_palm_oil_n'].unique()
# Out:
# array(['not specified', 0.0, 1.0, 2.0], dtype=object)

# %%
ingredients_from_palm_oil_agg = data['ingredients_from_palm_oil_n'].value_counts()

# %%
print(ingredients_from_palm_oil_agg)
# Out:
# 0.0              216001
# not specified     68482
# 1.0                4401
# 2.0                  57
# Name: ingredients_from_palm_oil_n, dtype: int64

# %% [markdown]
# <a name='ingredients_that_may_be_from_palm_oil_n'></a>
# ### `ingredients_that_may_be_from_palm_oil_n`

# %%
data['ingredients_that_may_be_from_palm_oil_n'] = data['ingredients_that_may_be_from_palm_oil_n'].fillna('not specified')

# %%
data['ingredients_that_may_be_from_palm_oil_n'].nunique()
# Out:
# 8

# %%
data['ingredients_that_may_be_from_palm_oil_n'].unique()
# Out:
# array(['not specified', 0.0, 3.0, 1.0, 2.0, 5.0, 4.0, 6.0], dtype=object)

# %%
ingredients_that_may_be_from_palm_oil_n_agg = data['ingredients_that_may_be_from_palm_oil_n'].value_counts()

# %%
print(ingredients_that_may_be_from_palm_oil_n_agg)
# Out:
# 0.0              209493
# not specified     68482
# 1.0                9391
# 2.0                1259
# 3.0                 265
# 4.0                  45
# 5.0                   5
# 6.0                   1
# Name: ingredients_that_may_be_from_palm_oil_n, dtype: int64

# %% [markdown]
# <a name='4'></a>
# # 4. Data export

# %%
display(data.head(1))
print(data.info())
print(data.shape)
# Out:
#             code                                                url  \
# 0  0000000003087  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator        product_name ingredients_from_palm_oil_n  \
# 0  openfoodfacts-contributors  farine de blé noir               not specified
#
#   ingredients_that_may_be_from_palm_oil_n nutrition_grade_fr  energy_100g  \
# 0                           not specified      not specified  1031.871034
#
#     fat_100g  saturated-fat_100g  ...     additive_1     additive_2  \
# 0  10.771763            4.240857  ...  not specified  not specified
#
#       additive_3     additive_4     additive_5     additive_6     additive_7  \
# 0  not specified  not specified  not specified  not specified  not specified
#
#       additive_8     additive_9    additive_10
# 0  not specified  not specified  not specified
#
# [1 rows x 33 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288941 entries, 0 to 320771
# Data columns (total 33 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   code                                     288941 non-null  object
#  1   url                                      288941 non-null  object
#  2   creator                                  288941 non-null  object
#  3   product_name                             288941 non-null  object
#  4   ingredients_from_palm_oil_n              288941 non-null  object
#  5   ingredients_that_may_be_from_palm_oil_n  288941 non-null  object
#  6   nutrition_grade_fr                       288941 non-null  object
#  7   energy_100g                              288941 non-null  float64
#  8   fat_100g                                 288941 non-null  float64
#  9   saturated-fat_100g                       288941 non-null  float64
#  10  carbohydrates_100g                       288941 non-null  float64
#  11  sugars_100g                              288941 non-null  float64
#  12  proteins_100g                            288941 non-null  float64
#  13  salt_100g                                288941 non-null  float64
#  14  sodium_100g                              288941 non-null  float64
#  15  date_created                             288941 non-null  datetime64[ns]
#  16  last_modified                            288941 non-null  datetime64[ns]
#  17  country_1                                288941 non-null  object
#  18  country_2                                288941 non-null  object
#  19  country_3                                288941 non-null  object
#  20  brand_1                                  288941 non-null  object
#  21  brand_2                                  288941 non-null  object
#  22  brand_3                                  288941 non-null  object
#  23  additive_1                               288941 non-null  object
#  24  additive_2                               288941 non-null  object
#  25  additive_3                               288941 non-null  object
#  26  additive_4                               288941 non-null  object
#  27  additive_5                               288941 non-null  object
#  28  additive_6                               288941 non-null  object
#  29  additive_7                               288941 non-null  object
#  30  additive_8                               288941 non-null  object
#  31  additive_9                               288941 non-null  object
#  32  additive_10                              288941 non-null  object
# dtypes: datetime64[ns](2), float64(8), object(23)
# memory usage: 83.0+ MB
# None
# (288941, 33)

# %%
data.to_csv('cleaned_data.csv', sep=',', index=False)
